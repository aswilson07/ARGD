# %%
import numpy as np
import nodepy 
import matplotlib.pyplot as plt
import sys
import scipy as sp
from scipy import io
# %matplotlib inline

# %%
##IMPORT Hamiltonian matlab file and plot it

# %%
from scipy.io import loadmat
x = loadmat('losses_ham.mat')


plt.figure(figsize = (12, 8))
plt.loglog(nrange, x['storage'][0,0:-1], label='GD ($p=2$)', marker = 'd',markevery = [0,50,100,1000],linestyle = 'dashed',linewidth=3)
plt.loglog(nrange, x['storage'][2,0:-1], label='NAG ($p=2$)', marker = '*',markevery = [0,150,500,1500],linestyle = '-.',linewidth=3)
plt.loglog(nrange, x['storage'][1,0:-1], label='RGD ($p=4$)', marker = 'x',markevery = [0,200,300,450,1200,10500,100000,150000,400000,800000], linestyle = ':',linewidth=3)
plt.loglog(nrange, x['storage'][3,0:-1], label='ARGD ($p=4$)', marker = 'o',markevery = [75,250,550,5000,10000,100000,150000,400000,800000],linewidth=3)
plt.legend()
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Objective')
plt.rcParams.update({'font.size': 20})
